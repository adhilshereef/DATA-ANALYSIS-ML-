# %% [markdown]
# # converting the image from pixel to another pixel format
# import os
#
# a=cv2.imread('/home/cocoslabs/Downloads/sample.jpeg')
# cv2.imshow('img',a)
# (x,y,z)=a.shape
# print((x,y,z))
# for i in range(0,x):
#     for j in range(0,y):
#         for k in range(0,z):
#             if i%10==0 or j%10==0:
#                 a[i][j][k]=0
# cv2.imshow('img1',a)
# cv2.waitKey(0)

# %% [markdown]
# # takin image from one folder and converting the pixel and saving to another folder
# import cv2
# import os
# import glob
# import shutil
# img_dir = "/home/cocoslabs/Downloads/test1/" # Enter Directory of all images
# save_dir= "/home/cocoslabs/Downloads/test2/"
# for f1 in os.listdir(img_dir):
#     img = cv2.imread(img_dir+f1)
#     img1=img
#     (x,y,z)=img1.shape
#     for i in range(0,x):
#         for j in range(0,y):
#             for k in range(0,z):
#                 if i%10==0 or j%10==0:
#                     img1[i][j][k]=0
#     cv2.imwrite(save_dir+f1,img)

# %%
# finding how much directories and files in folders and finding sub-files
import os
for dirpath,dirnames,filenames in os.walk("/home/cocoslabs/Downloads/VOCdevkit"):
    print("current path:",dirpath)
    print("directories:",dirnames)
    print("files:",filenames)
    print()
# Out:
# current path: /home/cocoslabs/Downloads/VOCdevkit
# directories: ['VOC2007']
# files: []
#
# current path: /home/cocoslabs/Downloads/VOCdevkit/VOC2007
# directories: ['ImageSets', 'JPEGImages', 'SegmentationObject', 'SegmentationClass', 'sample', 's1']
# files: []
#
# current path: /home/cocoslabs/Downloads/VOCdevkit/VOC2007/ImageSets
# directories: ['Layout', 'Main', 'Segmentation']
# files: []
#
# current path: /home/cocoslabs/Downloads/VOCdevkit/VOC2007/ImageSets/Layout
# directories: []
# files: ['trainval.txt', 'train.txt', 'val.txt']
#
# current path: /home/cocoslabs/Downloads/VOCdevkit/VOC2007/ImageSets/Main
# directories: []
# ...

# %%
import glob

# %%
d="/home/cocoslabs/Downloads/VOCdevkit"
print(glob.glob(d+'/*'))
# Out:
# ['/home/cocoslabs/Downloads/VOCdevkit/VOC2007']

# %%
files=glob.iglob(".")

# %%
files
# Out:
# <generator object _iglob at 0x7fbe9d617d68>

# %%
next(files)
# Out:
# '.'

# %%
next(files)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-47-0179d31ffe29> in <module>
# ----> 1 next(files)
#
# StopIteration:

# %%
a=[1,2,3,4,5]

# %%
sum(a)
# Out:
# 15

# %%
num = []
for i in range(1,2):
    num.append((input().split(',')))

print(int(sum(num)))
# Out:
# 1 2 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-557603e6b63c> in <module>
#       3     num.append((input().split(',')))
#       4
# ----> 5 print(int(sum(num)))
#       6
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
inputs = [input().split(',') for i in range(3)]
# Out:
# 1
# 2
# 3

# %%
list_of_inputs = input().split(',')
# Out:
# 1 2 3 4 5
