# %%
import os
import shutil
for i in os.listdir('/home/cocoslabs/Downloads/jpg_images'):
    print(i)
# Out:
# img1.jpeg
# img2.jpeg
# img5.jpeg
# img3.jpeg
# img4.jpeg
# img6.jpeg

# %%
for i in os.listdir('/home/cocoslabs/Downloads/jpg_images'):
    shutil.copy('/home/cocoslabs/Downloads/jpg_images'+'/')

# %%
os.listdir('/home/cocoslabs/Downloads/jpg_images')
# Out:
# ['img1.jpeg', 'img2.jpeg', 'img5.jpeg', 'img3.jpeg', 'img4.jpeg', 'img6.jpeg']

# %%
import os 
from os.path import isfile,join
import shutil
jpg_images="/home/cocoslabs/Downloads/VOCdevkit/VOC2007/JPEGImages/"
anotations="/home/cocoslabs/Downloads/VOCdevkit/VOC2007/s1/"

# %%
jp=[f for f in os.listdir(jpg_images) if isfile(join(jpg_images,f))]
an=[a for a in os.listdir(anotations) if isfile(join(anotations,a))]

# %%
# for i in jp:
#     for j in an:
#         if i[:-4] ==j[:-4]:
#             print(i)
#             print(j)
count=0
for img in os.listdir(jpg_images):
    if(os.path.exists(anotations+img.split('.')[0]+'.xml')):
        print(img)
        print((jpg_images+img.split('.')[0]+'.xml').split('/')[-1]) 
        
    else:
       
        os.remove(jpg_images+img)
        count+=1
print(count)
# Out:
# 006835.jpg
# 006835.xml
# 009667.jpg
# 009667.xml
# 001766.jpg
# 001766.xml
# 002906.jpg
# 002906.xml
# 007383.jpg
# 007383.xml
# 003554.jpg
# 003554.xml
# 006367.jpg
# 006367.xml
# 001061.jpg
# 001061.xml
# 004258.jpg
# 004258.xml
# 005653.jpg
# 005653.xml
# 009568.jpg
# 009568.xml
# 007799.jpg
# 007799.xml
# 007656.jpg
# 007656.xml
# 004905.jpg
# 004905.xml
# 002470.jpg
# 002470.xml
# 001311.jpg
# 001311.xml
# 008966.jpg
# 008966.xml
# 007672.jpg
# 007672.xml
# 003861.jpg
# 003861.xml
# 007877.jpg
# 007877.xml
# 002625.jpg
# 002625.xml
# 006484.jpg
# 006484.xml
# 008858.jpg
# 008858.xml
# 000929.jpg
# 000929.xml
# 003259.jpg
# 003259.xml
# 007431.jpg
# 007431.xml
# 001810.jpg
# 001810.xml
# 007482.jpg
# 007482.xml
# 001543.jpg
# 001543.xml
# 005297.jpg
# 005297.xml
# 005841.jpg
# 005841.xml
# 007940.jpg
# 007940.xml
# 006459.jpg
# 006459.xml
# 003681.jpg
# 003681.xml
# 001324.jpg
# 001324.xml
# 006366.jpg
# 006366.xml
# 002347.jpg
# 002347.xml
# 005660.jpg
# 005660.xml
# ...

# %%
jp=[f for f in v if isfile(f)]

# %%
print(len(jp))
# Out:
# 0

# %%
import emoji

# %%
# !pip install emoji
# Out:
# ...
#      |████████████████████████████████| 51kB 562kB/s eta 0:00:01
# ...
#   Stored in directory: /home/cocoslabs/.cache/pip/wheels/86/09/26/f944015841423cd516e8a97f30e29be59e53461aea8b7d3458
# Successfully built emoji
# ...

# %%
print(emoji.emojize(":thumbs_up:"))
# Out:
# 👍

# %%
print("\U0001F600")
# Out:
# 😀

# %%
import os
for i in os.listdir("/home/cocoslabs/Downloads/test2"):
    print(i)
# Out:
# sample2.jpeg
# sample1.jpeg

# %%
print(os.stat("/home/cocoslabs/Downloads/test2"))
# Out:
# os.stat_result(st_mode=16893, st_ino=27660775, st_dev=66306, st_nlink=2, st_uid=1000, st_gid=1000, st_size=4096, st_atime=1566542700, st_mtime=1566542686, st_ctime=1566542686)
